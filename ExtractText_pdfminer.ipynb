# %% [markdown]
# <a href="https://colab.research.google.com/github/chinmay27/hello-future/blob/master/ExtractText_pdfminer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pdfminer
# Out:
# ...
#      |████████████████████████████████| 4.2MB 1.3MB/s
# ...
#      |████████████████████████████████| 13.7MB 306kB/s
# ...
#   Created wheel for pdfminer: filename=pdfminer-20191125-cp36-none-any.whl size=6140086 sha256=610691fd564cf45d6dbe6f1c03644aeac534b32991e6d28a7e94b267e1a514ec
#   Stored in directory: /root/.cache/pip/wheels/e1/00/af/720a55d74ba3615bb4709a3ded6dd71dc5370a586a0ff6f326
# Successfully built pdfminer
# ...

# %% [markdown]
# Import pdf files

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-46177fb5-4e46-4687-b27e-519251a62838" name="files[]" multiple disabled />
#      <output id="result-46177fb5-4e46-4687-b27e-519251a62838">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving one.pdf to one.pdf
# Saving two.pdf to two.pdf

# %% [markdown]
# Import PDFMINER's libraries

# %%
import io
 
from pdfminer.converter import TextConverter
from pdfminer.pdfinterp import PDFPageInterpreter
from pdfminer.pdfinterp import PDFResourceManager
from pdfminer.pdfpage import PDFPage

# %%
def extract_text_from_pdf(pdf_path):
    resource_manager = PDFResourceManager()
    fake_file_handle = io.StringIO()
    converter = TextConverter(resource_manager, fake_file_handle)
    page_interpreter = PDFPageInterpreter(resource_manager, converter)
 
    with open(pdf_path, 'rb') as fh:
        for page in PDFPage.get_pages(fh, 
                                      caching=True,
                                      check_extractable=True):
            page_interpreter.process_page(page)
 
        text = fake_file_handle.getvalue()
 
    # close open handles
    converter.close()
    fake_file_handle.close()
 
    if text:
        return text

# %%
pdftotext=extract_text_from_pdf('one.pdf')
print(pdftotext)
# Out:
# Schwab Individual 401(k)  Basic Plan DocumentThis booklet contains the following important information about the Schwab Individual 401(k) Plan.  Please review it and keep it for your records.What’s Inside:• Basic Plan Document• IRS Opinion LetterContentsIndividual 401(k) Basic Plan Document ...................Section 1IRS Opinion Letter ..................................Section 2Item #REG47279-01.inddJob #Page #CS21566-121 of 40Spellcheck: NoColor Seps: NoFold Dummy: NoRound5Last Modiﬁ ed11-14-2014 1:17 PMTEAMStudioPrev. StudioYates, JohnSuen, AllenSETUPBleedNoneCONTENTPlaced GraphicsInksLOG-CSRtlPrf-BLK.eps (14.29%) BlackTrafﬁ c Mgr.Ana MottaTrim8.5” x 11”Art DirectorKevin NitsosLiveNoneAcct. Mgr.Maribeth McLarenFontsITC Franklin Gothic Std (Medium; OpenType)GraphicsJanet LevyDETAILSJob TypeLithoMech Scale100%Output Size100%Schwab Individual 401(k) Basic Plan DocumentSection 1Item #REG47279-01.inddJob #Page #CS21566-122-1 of 40Spellcheck: NoColor Seps: NoFold Dummy: NoRound5Last Mod
# ...

# %% [markdown]
# will not work since it does not differentiate a paragraph. And at the EOL, it justr begins with firsxt letter ofg next word without leaving even a single space.

# %%
pdftotext
# Out:
# 'Schwab Individual 401(k)  Basic Plan DocumentThis booklet contains the following important information about the Schwab Individual 401(k) Plan.  Please review it and keep it for your records.What’s Inside:• Basic Plan Document• IRS Opinion Letter\x0cContentsIndividual 401(k) Basic Plan Document ...................Section 1IRS Opinion Letter ..................................Section 2\x0cItem #REG47279-01.inddJob #Page #CS21566-121 of 40Spellcheck: NoColor Seps: NoFold Dummy: NoRound5Last Modiﬁ ed11-14-2014 1:17 PMTEAMStudioPrev. StudioYates, JohnSuen, AllenSETUPBleedNoneCONTENTPlaced GraphicsInksLOG-CSRtlPrf-BLK.eps (14.29%) BlackTrafﬁ c Mgr.Ana MottaTrim8.5” x 11”Art DirectorKevin NitsosLiveNoneAcct. Mgr.Maribeth McLarenFontsITC Franklin Gothic Std (Medium; OpenType)GraphicsJanet LevyDETAILSJob TypeLithoMech Scale100%Output Size100%Schwab Individual 401(k) Basic Plan DocumentSection 1\x0cItem #REG47279-01.inddJob #Page #CS21566-122-1 of 40Spellcheck: NoColor Seps: NoFold Dummy: NoR
# ...

# %% [markdown]
# Now wil try another method keeping 4 spacces as delimiter

# %%
import re

# %%
# !pip install textract
# Out:
# ...
#      |████████████████████████████████| 8.9MB 1.4MB/s
# ...
#      |████████████████████████████████| 5.6MB 45.4MB/s
# ...
#      |████████████████████████████████| 32.8MB 128kB/s
# ...
#      |████████████████████████████████| 102kB 11.7MB/s
# ...
#      |████████████████████████████████| 112kB 56.1MB/s
# ...
#      |████████████████████████████████| 51kB 6.5MB/s
# ...
#      |████████████████████████████████| 112kB 46.5MB/s
# ...
#      |████████████████████████████████| 143kB 52.3MB/s
# ...
#      |████████████████████████████████| 13.7MB 174kB/s
# ...
#      |████████████████████████████████| 81kB 10.6MB/s
# ...
#      |████████████████████████████████| 112kB 53.5MB/s
# ...
#   Created wheel for python-pptx: filename=python_pptx-0.6.18-cp36-none-any.whl size=275706 sha256=1cb4dfceb7228bba65e649e614ce445a143e29ca6733021b77cdf2a6d1490a74
#   Stored in directory: /root/.cache/pip/wheels/1f/1f/2c/29acca422b420a0b5210bd2cd7e9669804520d602d2462f20b
# ...

# %%
import textract

# %%
text = textract.process('one.pdf')
type (text)
# Out:
# bytes

# %%
text = text.decode('ISO-8859-1')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-92fb719e20f3> in <module>()
# ----> 1 text = text.decode('ISO-8859-1')
#
# AttributeError: 'str' object has no attribute 'decode'

# %%
print (re.split('\s{4,}',text))
# Out:
# ['Schwab Individual 401(k)  \nBasic Plan Document\n\nThis booklet contains the following important information about the Schwab Individual 401(k) Plan.  \nPlease review it and keep it for your records.\n\nWhatâ\x80\x99s Inside:\n\nâ\x80¢ Basic Plan Document\n\nâ\x80¢ IRS Opinion Letter\n\n\x0cContents\nIndividual 401(k) Basic Plan Document . . . . . . . . . . . . . . . . . . . Section 1\nIRS Opinion Letter . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . Section 2\n\n\x0cS\ne\nc\nt\ni\no\nn\n \n1\n\nSchwab Individual 401(k) \nBasic Plan Document\n\n\x0cQualified Retirement Plan and Trust\nDefined Contribution Basic Plan Document 04\n\nS\ne\nc\nt\ni\no\nn\n \n1\n\nDeï¬\x81 nitions\n2009 RMD  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .3\nActual Deferral Percentage (ADP) . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .3\nAdopting Employer  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# ...

# %%
print (re.split('\n\n',text))
# Out:
# ['Schwab Individual 401(k)  \nBasic Plan Document', 'This booklet contains the following important information about the Schwab Individual 401(k) Plan.  \nPlease review it and keep it for your records.', 'Whatâ\x80\x99s Inside:', 'â\x80¢ Basic Plan Document', 'â\x80¢ IRS Opinion Letter', '\x0cContents\nIndividual 401(k) Basic Plan Document . . . . . . . . . . . . . . . . . . . Section 1\nIRS Opinion Letter . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . Section 2', '\x0cS\ne\nc\nt\ni\no\nn\n \n1', 'Schwab Individual 401(k) \nBasic Plan Document', '\x0cQualified Retirement Plan and Trust\nDefined Contribution Basic Plan Document 04', 'S\ne\nc\nt\ni\no\nn\n \n1', 'Deï¬\x81 nitions\n2009 RMD  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .3\nActual Deferral Percentage (ADP) . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .3\nAdopting Employer  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# ...

# %%
text2 = re.split('\n\n',text)
print(text2[31])
print(text2[32])
print(text2[33])
# Out:
# Alternate Payee
# Means any Spouse, former Spouse, child, or other dependent of a
# Participant who is recognized by a Domestic Relations Order as having a
# right to receive all, or a portion of, the beneï¬ ts payable under the Plan
# with respect to such Participant.
# Annual Additions
# Means the sum of the following amounts credited to a Participant for the
# Limitation Year:
# a.  Employer Contributions;

# %%
print(text2[4])
# Out:
# The prior-year testing method described below will apply to this Plan.
#
# 14 Individual 401(k) Basic Plan Document
#
# 3.  Prior-Year TestingâThe ADP for a Plan Year for Participants who are
#
# Highly Compensated Employees for each Plan Year and the prior yearâs
# ADP for Participants who were non-Highly Compensated Employees for
# the prior Plan Year must satisfy one of the following tests.
#
# a.  The ADP for a Plan Year for Participants who are Highly
#
# Compensated Employees for the Plan Year will not exceed the prior
# yearâs ADP for Participants who were non-Highly Compensated
# Employees for the prior Plan Year multiplied by 1.25; or
#
# b.  The ADP for a Plan Year for Participants who are Highly
#
# Compensated Employees for the Plan Year will not exceed the prior
# yearâs ADP for Participants who were non-Highly Compensated
# Employees for the prior Plan Year multiplied by 2.0, provided that
# the ADP for Participants who are Highly Compensated Employees
# ...
